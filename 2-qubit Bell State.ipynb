# %%
from qiskit import QuantumCircuit

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
qc.draw(output='mpl')
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[4], line 4
#       2 qc.h(0)
#       3 qc.cx(0,1)
# ----> 4 qc.draw(output='mpl')
#
# File ~\anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py:3428, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#    3425 # pylint: disable=cyclic-import
#    3426 from qiskit.visualization import circuit_drawer
# -> 3428 return circuit_drawer(
#    3429     self,
#    3430     scale=scale,
#    3431     filename=filename,
#    3432     style=style,
#    3433     output=output,
#    3434     interactive=interactive,
#    3435     plot_barriers=plot_barriers,
#    3436     reverse_bits=reverse_bits,
#    3437     justify=justify,
# ...
